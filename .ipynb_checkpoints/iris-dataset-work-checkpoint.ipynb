# %%
# http://machinelearningmastery.com/machine-learning-in-python-step-by-step/

# %%
# Check the versions of libraries

# Python version
import sys
print('Python: {}'.format(sys.version))
# scipy
import scipy
print('scipy: {}'.format(scipy.__version__))
# numpy
import numpy
print('numpy: {}'.format(numpy.__version__))
# matplotlib
# %matplotlib inline
import matplotlib
print('matplotlib: {}'.format(matplotlib.__version__))
# pandas
import pandas
print('pandas: {}'.format(pandas.__version__))
# scikit-learn
import sklearn
print('sklearn: {}'.format(sklearn.__version__))
# Out:
# Python: 2.7.11 | 64-bit | (default, Jun 11 2016, 03:41:56)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
# scipy: 0.17.1
# numpy: 1.10.4
# matplotlib: 1.5.1
# pandas: 0.18.0
# sklearn: 0.17

# %%
# Load libraries
import pandas
from pandas.tools.plotting import scatter_matrix
import matplotlib.pyplot as plt
# %matplotlib inline 
# %pylab inline
pylab.rcParams['figure.figsize'] = (10, 6)

from sklearn import cross_validation
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Load dataset
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
# url of the data 
names = ['sepal-length', 'sepal-width', 'petal-length', 'petal-width', 'class']
# comma separated! 
dataset = pandas.read_csv(url, names=names)
# sets column titles to the list we just created  
print "done"
# Out:
# done

# %%
print dataset.shape
#will print instances (rows) and attributes (columns)
# Out:
# (150, 5)

# %%
print dataset.head(20)
#will allow us to eyeball our data, the first 20 rows of it (0 - 19)
# Out:
#     sepal-length  sepal-width  petal-length  petal-width        class
# 0            5.1          3.5           1.4          0.2  Iris-setosa
# 1            4.9          3.0           1.4          0.2  Iris-setosa
# 2            4.7          3.2           1.3          0.2  Iris-setosa
# 3            4.6          3.1           1.5          0.2  Iris-setosa
# 4            5.0          3.6           1.4          0.2  Iris-setosa
# 5            5.4          3.9           1.7          0.4  Iris-setosa
# 6            4.6          3.4           1.4          0.3  Iris-setosa
# 7            5.0          3.4           1.5          0.2  Iris-setosa
# 8            4.4          2.9           1.4          0.2  Iris-setosa
# 9            4.9          3.1           1.5          0.1  Iris-setosa
# 10           5.4          3.7           1.5          0.2  Iris-setosa
# 11           4.8          3.4           1.6          0.2  Iris-setosa
# ...

# %%
print dataset.describe()
#This provides descriptive statistics: the count, mean, the min and max values as well as some percentiles.
# Out:
#        sepal-length  sepal-width  petal-length  petal-width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# class distribution
print dataset.groupby('class').size()
# looks at instances (rows) that belong to each class
# Out:
# class
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %%
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# make box and whisker plots
dataset.plot(kind='box', subplots=True, layout=(2,2), sharex=False, sharey=False)
plt.show()

# %%
#histogram
dataset.hist()
plt.show()

# %%
# scatter plot matrix
# use to check relationships between input variables 
scatter_matrix(dataset)
plt.show()

# %%
#We will split the loaded dataset into two, 80% of which we will use to train our models
#and 20% that we will hold back as a validation dataset.
# https://en.wikipedia.org/wiki/Cross-validation_(statistics)

# Split-out validation dataset
array = dataset.values
X = array[:,0:4]
Y = array[:,4]
validation_size = 0.20
seed = 7
X_train, X_validation, Y_train, Y_validation = cross_validation.train_test_split(X, Y, test_size=validation_size, random_state=seed)

# %%
# Test options and evaluation metric
num_folds = 10
num_instances = len(X_train)
seed = 7
scoring = 'accuracy'

#Creates 10 sets, will train on 9, test on 1, repeat for all combinations 
# "accuracy" metric = number of correctly predicted instances/total number of instances in the dataset as %

# %%
'''
Evaluate 6 different algorithms: 
Logistic Regression (LR) (simple linear)
Linear Discriminant Analysis (LDA) (simple linear)
K-Nearest Neighbors (KNN).
Classification and Regression Trees (CART).
Gaussian Naive Bayes (NB).
Support Vector Machines (SVM).
'''
# Out:
# '\nEvaluate 6 different algorithms: \nLogistic Regression (LR) (simple linear)\nLinear Discriminant Analysis (LDA) (simple linear)\nK-Nearest Neighbors (KNN).\nClassification and Regression Trees (CART).\nGaussian Naive Bayes (NB).\nSupport Vector Machines (SVM).\n'

# %%
# Spot Check Algorithms
models = []
models.append(('LR', LogisticRegression()))
models.append(('LDA', LinearDiscriminantAnalysis()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('CART', DecisionTreeClassifier()))
models.append(('NB', GaussianNB()))
models.append(('SVM', SVC()))
# evaluate each model in turn
results = []
names = []
for name, model in models:
	kfold = cross_validation.KFold(n=num_instances, n_folds=num_folds, random_state=seed)
	cv_results = cross_validation.cross_val_score(model, X_train, Y_train, cv=kfold, scoring=scoring)
	results.append(cv_results)
	names.append(name)
	msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
	print(msg)
# Out:
# LR: 0.966667 (0.040825)
# LDA: 0.975000 (0.038188)
# KNN: 0.983333 (0.033333)
# CART: 0.975000 (0.038188)
# NB: 0.975000 (0.053359)
# SVM: 0.991667 (0.025000)

# %%
# Compare Algorithms
fig = plt.figure()
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names)
plt.show()

# %%
# Make predictions on validation dataset
knn = KNeighborsClassifier()
knn.fit(X_train, Y_train)
predictions = knn.predict(X_validation)
print(accuracy_score(Y_validation, predictions))
print(confusion_matrix(Y_validation, predictions))
print(classification_report(Y_validation, predictions))
# Out:
# 0.9
# [[ 7  0  0]
#  [ 0 11  1]
#  [ 0  2  9]]
#              precision    recall  f1-score   support
#
# Iris-setosa       1.00      1.00      1.00         7
# Iris-versicolor       0.85      0.92      0.88        12
# Iris-virginica       0.90      0.82      0.86        11
#
# avg / total       0.90      0.90      0.90        30
